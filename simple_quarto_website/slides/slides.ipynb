# %% [markdown]
# ---
# title: "My Presentation"
# format:
#     revealjs:
#         code-fold: true
# bibliography: ../reference.bib
# ---
#
# ## First slide
#
# - Welcome to my slide
#
# ## Second slide
#
# ![Data Image](images/luna.png)
# ![Analysis Image](images/Xiaolong_Zhou.png)
#
# ## Third slide
#
# - What's in here
# - How chat GPT can transform autodidactic experiences and open education?[@firat2023chat]

# %%
#| code-fold: true
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y = np.cos(x)

plt.plot(x, y)
plt.title("Sample Cosine Wave")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()
